# %% [markdown]
# # Preprocess

# %%
import pandas as pd
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Tseh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tseh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Tseh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
CVs = pd.read_csv("C:\\Users\\Tseh\\Downloads\\resumes.csv", delimiter = ';', nrows=20000)
vacancies = pd.read_csv("C:\\Users\\Tseh\\Downloads\\vacancies.csv", nrows=20000)

# %%
CVs = CVs.drop(columns = ['Пол, возраст', 'ЗП', 'Обновление резюме', 'Авто'])
CVs['resume'] = CVs.apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
CVs = CVs[['resume']]
CVs.insert(0, 'id', range(1, len(CVs) + 1))
CVs.head()
# Out:
#    id                                             resume
# 0   1  Системный администратор Советск (Калининградск...
# 1   2  Технический писатель Королев , не готов к пере...
# 2   3  Оператор Тверь , не готова к переезду , не гот...
# 3   4  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4   5  Региональный менеджер по продажам Москва , не ...

# %%
vacancies = vacancies.drop(columns = ['Ids', 'Employer', 'Salary', 'From', 'To', 'Published at', 'Professional roles', 'Specializations', 'Profarea names'])
vacancies['vacancies'] = vacancies.apply(lambda row: ' '.join(row.dropna().astype(str)), axis=1)
vacancies = vacancies[['vacancies']]
vacancies.insert(0, 'id', range(1, len(vacancies) + 1))
vacancies.head()
# Out:
#    id                                          vacancies
# 0   1  Golang Developer (Кипр) От 3 до 6 лет Полный д...
# 1   2  Е-mail маркетолог От 1 года до 3 лет Полный де...
# 2   3  Оператор call-центра (удаленно) От 1 года до 3...
# 3   4  Ведущий SMM специалист От 1 года до 3 лет Полн...
# 4   5  UX/UI Designer От 1 года до 3 лет Полный день ...

# %%
def preprocess_text(text):
    # Tokenization
    tokens = word_tokenize(str(text).lower())   

    # stop words  
    stop_words = set(stopwords.words('russian'))
    tokens = [word for word in tokens if word.isalpha() and word not in stop_words]

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    return ' '.join(tokens)

# %%
CVs['Processed_Resume'] = CVs['resume'].apply(preprocess_text)
vacancies['Processed_Description'] = vacancies['vacancies'].apply(preprocess_text)

# %% [markdown]
# # TFid Vectorization

# %%
# Vectorization
tfidf = TfidfVectorizer()
tfidf_matrix_cv = tfidf.fit_transform(CVs['Processed_Resume'])
tfidf_matrix_vacancies = tfidf.transform(vacancies['Processed_Description'])

# %%
# cosine similarity 
similarity_matrix = cosine_similarity(tfidf_matrix_cv, tfidf_matrix_vacancies)

matched_indices = similarity_matrix.argmax(axis=1)
CVs['Matched_Vacancy_ID'] = matched_indices

# %%
CVs['Matched_Vacancy_Description'] = vacancies.loc[matched_indices, 'vacancies'].values

# %%
# new matched dataset   
matched_data = pd.merge(CVs, vacancies, left_on='Matched_Vacancy_ID', right_index=True, suffixes=('_Resume', '_Vacancy'))

# %%
matched_data_final = matched_data[['Processed_Resume', 'Processed_Description']]

# %%
# 16416  технический писатель года лет полный день писа...
# 17826  технический писатель года лет полный день писа...
# 18095  технический писатель года лет полный день писа...
# 18101  технический писатель года лет полный день писа...
# 2      руководитель проектов лет удаленная работа ком...
# 2435   руководитель проектов лет удаленная работа ком...
# 4255   руководитель проектов лет удаленная работа ком...
# 4336   руководитель проектов лет удаленная работа ком...
# 4743   руководитель проектов лет удаленная работа ком...
# 5152   руководитель проектов лет удаленная работа ком...
# 6134   руководитель проектов лет удаленная работа ком...
# 6326   руководитель проектов лет удаленная работа ком...
# 6940   руководитель проектов лет удаленная работа ком...
# 8030   руководитель проектов лет удаленная работа ком...
# 11149  руководитель проектов лет удаленная работа ком...
# 11181  руководитель проектов лет удаленная работа ком...
# 12154  руководитель проектов лет удаленная работа ком...
# 13475  руководитель проектов лет удаленная работа ком...
# 15128  руководитель проектов лет удаленная работа ком...
# 15552  руководитель проектов лет удаленная работа ком...
# 15976  руководитель проектов лет удаленная работа ком...
# 16931  руководитель проектов лет удаленная работа ком...
# 17648  руководитель проектов лет удаленная работа ком...
# 17894  руководитель проектов лет удаленная работа ком...
# 18783  руководитель проектов лет удаленная работа ком...
# 19258  руководитель проектов лет удаленная работа ком...
# 3      года лет полный день illustrator indesign phot...
# 324    года лет полный день illustrator indesign phot...
# 1893   года лет полный день illustrator indesign phot...
# 2695   года лет полный день illustrator indesign phot...
# 5696   года лет полный день illustrator indesign phot...
# 10884  года лет полный день illustrator indesign phot...
# 15906  года лет полный день illustrator indesign phot...

# %% [markdown]
# # Doc2Vec

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %%
tagged_data_cv = [TaggedDocument(words=doc, tags=[i]) for i, doc in enumerate(CVs['Processed_Resume'])]
tagged_data_vacancies = [TaggedDocument(words=doc, tags=[i]) for i, doc in enumerate(vacancies['Processed_Description'])]

# %%
# Training 
model_cv = Doc2Vec(vector_size=100, window=5, min_count=1, workers=4, epochs=20)
model_cv.build_vocab(tagged_data_cv)
model_cv.train(tagged_data_cv, total_examples=model_cv.corpus_count, epochs=model_cv.epochs)

model_vacancies = Doc2Vec(vector_size=100, window=5, min_count=1, workers=4, epochs=20)
model_vacancies.build_vocab(tagged_data_vacancies)
model_vacancies.train(tagged_data_vacancies, total_examples=model_vacancies.corpus_count, epochs=model_vacancies.epochs)

# %%
similarities = []
for i in range(len(CVs)):
    similarity_scores = model_vacancies.docvecs.most_similar([model_cv.infer_vector(word_tokenize(CVs['Processed_Resume'][i]))], topn=1)
    similarities.append((i, similarity_scores[0][0], similarity_scores[0][1]))
# Out:
# C:\Users\Tseh\AppData\Local\Temp\ipykernel_18460\3399075100.py:3: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   similarity_scores = model_vacancies.docvecs.most_similar([model_cv.infer_vector(word_tokenize(CVs['Processed_Resume'][i]))], topn=1)

# %%
 similarities_df = pd.DataFrame(similarities, columns=['CV_Index', 'Matched_Vacancy_Index', 'Similarity_Score'])

matched_data = pd.merge(CVs, similarities_df, left_index=True, right_on='CV_Index')
matched_data = matched_data.merge(vacancies, left_on='Matched_Vacancy_Index', right_index=True)

# %%
 matched_data_final = matched_data[['Processed_Resume', 'Processed_Description']]
# Out:
#                                         Processed_Resume  \
# 0      системный администратор советск калининградска...
# 1497   менеджер сопровождению клиентов готов переезду...
# 1      технический писатель королев готов переезду го...
# 5366   руководитель группы технической поддержки моск...
# 17347  ведущий программист сочи готова переезду москв...
# ...                                                  ...
# 19983  менеджер ярославль готов переезду готов редким...
# 19985  махачкала готов переезду готов командировкам ч...
# 19993  оператор группы ввода данных маркета московска...
# 19995  технический специалист екатеринбург чкаловская...
# 19999  монтажник слаботочных систем москва бунинская ...
#
#                                    Processed_Description
# 0      менеджер контроля качества отдел аналитики опы...
# 1497   менеджер контроля качества отдел аналитики опы...
# 1      frontend engineer злым марсианам удаленная раб...
# 5366   frontend engineer злым марсианам удаленная раб...
# 17347  frontend engineer злым марсианам удаленная раб...
# ...                                                  ...
# 19983  ведущий разработчик года лет гибкий график про...
# 19985  приложения io опыта гибкий график откликнуться...
# 19993  senior qa tester дистанционно лет удаленная ра...
# 19995  системный администратор года лет полный день о...
# 19999  data engineer торговое финансирование сделок г...
#
# [20000 rows x 2 columns]

# %%
matched_data_final.head(50)
# Out:
#                                         Processed_Resume  \
# 0      системный администратор советск калининградска...
# 1497   менеджер сопровождению клиентов готов переезду...
# 1      технический писатель королев готов переезду го...
# 5366   руководитель группы технической поддержки моск...
# 17347  ведущий программист сочи готова переезду москв...
# 2      оператор тверь готова переезду готова командир...
# 15806  ведущий специалист технической поддержке липец...
# 3      html cs j php базы данных фреймворки дизайн ин...
# 345    волгоград готов переезду готов командировкам п...
# 647    москва теплый стан готов переезду готов команд...
# 1709   руководитель проекта москва готов переезду гот...
# 2352   ведущий программист php тимлид архитектор нижн...
# 2960   product owner воронеж готова переезду готова р...
# 3069   full stack web разработчик краснодар готов пер...
# 3498   web москва готов переезду готов командировкам ...
# 3650   full stack разработчик ижевск готов переезду м...
# 3770   developer краснодар готов переезду готов коман...
# 3926   самара готов переезду нидерланды россия велико...
# 4849   москва комсомольская хочу переехать сша швейца...
# 5341   старший программист тимлид руководитель проект...
# 6869   qa engineer mobile москва готова переезду гото...
# 7620   junior vue j зеленоград готов переезду москва ...
# 7971   vue екатеринбург чкаловская готов переезду ека...
# 8453   москва готов переезду готов командировкам полн...
# 8495   программист пенза готов переезду готов команди...
# 9423   разработчик golang node j иваново ивановская о...
# 9578   devops инженер самара готов переезду готов ком...
# 9803   киров готова переезду готова командировкам пол...
# 10159  web разработчик вышний волочек готов переезду ...
# 10266  москва бауманская готов переезду готов команди...
# 11045  frontend developer таганрог готов переезду гот...
# 11199  tech lead team lead senior developer москва го...
# 12505  старший typescript разработчик москва готов пе...
# 12717  системный администратор новомосковск тульская ...
# # Word2Vec

# %%
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity

# %%
combined_corpus = list(CVs['Processed_Resume']) + list(vacancies['Processed_Description'])
word2vec_model = Word2Vec(sentences=combined_corpus, vector_size=100, window=5, min_count=1, workers=4)

# %%
def get_document_vector(tokens, model):
    vector = []
    for word in tokens:
        if word in model.wv:
            vector.append(model.wv[word])
    if vector:
        return sum(vector) / len(vector)
    else:
        return [0] * model.vector_size

# %%
CVs['Vector_Resume'] = CVs['Processed_Resume'].apply(lambda x: get_document_vector(x, word2vec_model))
vacancies['Vector_Description'] = vacancies['Processed_Description'].apply(lambda x: get_document_vector(x, word2vec_model))

# %%
similarity_matrix = cosine_similarity(list(CVs['Vector_Resume']), list(vacancies['Vector_Description']))

# %%
matched_indices = similarity_matrix.argmax(axis=1)
CVs['Matched_Vacancy_ID'] = matched_indices
CVs['Matched_Vacancy_Description'] = vacancies.loc[matched_indices, 'vacancies'].values

# %%
matched_data = pd.merge(CVs, vacancies, left_on='Matched_Vacancy_ID', right_index=True, suffixes=('_Resume', '_Vacancy'))
matched_data_final = matched_data[['Processed_Resume', 'Processed_Description']]

# %%
matched_data_final.head(50)
# Out:
#                                         Processed_Resume  \
# 0      системный администратор советск калининградска...
# 1855   системный аналитик тестировщик qa специалист о...
# 5225   специалист контролю качества волгоград готов п...
# 5945   системный аналитик тестировщик qa специалист о...
# 6874   специалист it системный администратор новосиби...
# 7016   специалист it алматы готов переезду готов редк...
# 7071   руководитель отдела маркетинга маркетолог seo ...
# 8998   специалист технической поддержки руководитель ...
# 11338  консультант сопровождению красноярск готов пер...
# 11814  оператор бухгалтер волжский готова переезду го...
# 12778  специалист it тольятти готова переезду готова ...
# 13388  специалист технической поддержки москва готов ...
# 15949  монтажник стерлитамак готов переезду готов ком...
# 19870  специалист ит отдела тюмень готов переезду гот...
# 1      технический писатель королев готов переезду го...
# 1669   липецк готов переезду австралия австрия респуб...
# 3580   удаленно москва готов переезду готов командиро...
# 4244   менеджер проекта астана готова переезду алматы...
# 5997   москва готов переезду готов редким командировк...
# 6772   специалист технической поддержки самара готов ...
# 8081   липецк готов переезду готов командировкам част...
# 8427   аналитик пятигорск готова переезду готова редк...
# 10672  рыбацкое готова переезду готова редким команди...
# 10986  международная готов переезду готов командировк...
# 11114  москва готова переезду готова командировкам ча...
# 12281  аналитик новосибирск готова переезду готова ре...
# 13010  руководитель проектов готова переезду готова к...
# 14638  тестировщик москва выхино готов переезду готов...
# 15127  маркетолог копирайтер администратор сайта сама...
# 16150  специалист ит новый уренгой готов переезду гот...
# 16498  москва готов переезду готов командировкам полн...
# 19693  junior python developer москва готов переезду ...
# 2      оператор тверь готова переезду готова командир...
# 3212   мастер ремонту компьютеров иваново ивановская ...
# 5907   мастер ремонту пк менеджер водитель администра...
# 6151   оператор электросталь готова переезду готова к...
